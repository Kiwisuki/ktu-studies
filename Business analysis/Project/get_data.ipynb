# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://Kiwisuki:labas123@real-estate.aaszr.mongodb.net/?retryWrites=true&w=majority")
db = client['Real-Estate']
collection = db['butai/kaune']
cursor = collection.find({})

# %%
# get data from database
collection = db['butai/kaune']
butaik = pd.DataFrame(list(collection.find()))
butaik.head()
# Out:
#                         _id House_number Flat_number   Area  Rooms  Floor  \
# 0  632b2252129f0622b19e3e9d                           55.00      2      3
# 1  632b2252129f0622b19e3e9f                           19.00      1      1
# 2  632b2252129f0622b19e3ea3           86              51.00      3      1
# 3  632b2252129f0622b19e3ea0           48              65.00      3      2
# 4  632b2252129f0622b19e3ea1           14              36.67      2      1
#
#    Floors  Year Building_type               Heating  ...    City  \
# 0       3  1997       Mūrinis             [dujinis]  ...  Kaunas
# 1       5  1972       Mūrinis           [centrinis]  ...  Kaunas
# 2       2  1996       Mūrinis  [elektra, kietukuru]  ...  Kaunas
# 3       5  1965       Mūrinis           [centrinis]  ...  Kaunas
# 4       1  1981       Mūrinis        [aeroterminis]  ...  Kaunas
#
#        District Dorm Days_active Views_per_day Saved_per_day Saves_per_views  \
# ...

# %%
collection = db['butai/vilniuje']
butaiv = pd.DataFrame(list(collection.find()))
butaiv.head()
# Out:
#                         _id House_number Flat_number    Area  Rooms  Floor  \
# 0  6320e9e7bc8fad6e15731c54                            49.62      2      5
# 1  6320e9e7bc8fad6e15731c4f           4F              374.00      5      1
# 2  6320e9e7bc8fad6e15731c58           41               94.62      3      1
# 3  6320e9e7bc8fad6e15731c51                            62.00      3      2
# 4  6320e9e7bc8fad6e15731c57           14              103.91      3      5
#
#    Floors  Year Building_type      Heating  ...     City         District  \
# 0       5  1990      Blokinis  [centrinis]  ...  Vilnius        Grigiškės
# 1       3  2005       Mūrinis    [dujinis]  ...  Vilnius     Karoliniškės
# 2       3  2018      Blokinis    [dujinis]  ...  Vilnius      Valakampiai
# 3       5  1985       Mūrinis  [centrinis]  ...  Vilnius   Naujoji Vilnia
# 4       6  1993       Mūrinis  [centrinis]  ...  Vilnius         Jeruzalė
#
# ...

# %%
collection = db['butu-nuoma/kaune']
nuomak = pd.DataFrame(list(collection.find()))
nuomak.head()
# Out:
#                         _id House_number Flat_number  Area  Rooms  Floor  \
# 0  632b883b129f0622b19e3fdd            3              72.0      3      3
# 1  632b883b129f0622b19e3fde           48           8  50.0      2      3
# 2  632b883b129f0622b19e3fdf           34           4  40.0      2      3
# 3  632b883b129f0622b19e3fe0           31              22.0      1      1
# 4  632b883b129f0622b19e3fe1           37           9  55.0      2      1
#
#    Floors                           Year Building_type         Heating  ...  \
# 0       5                           1980      Blokinis     [centrinis]  ...
# 1       3                           1954       Mūrinis     [centrinis]  ...
# 2       3                           2022       Mūrinis  [aeroterminis]  ...
# 3       5                           2022       Mūrinis       [elektra]  ...
# 4       2  1824 statyba, 2020 renovacija       Mūrinis   [geoterminis]  ...
#
# ...

# %%
collection = db['butu-nuoma/vilniuje']
nuomav = pd.DataFrame(list(collection.find()))
nuomav.head()
# Out:
#                         _id House_number Flat_number   Area  Rooms  Floor  \
# 0  6322759cc5cba579934445f8                           48.00      2      3
# 1  6322759cc5cba579934445f0                           64.00      3      5
# 2  6322759cc5cba579934445ef           20              45.00      2      5
# 3  6322759cc5cba579934445f6           26              46.46      2      4
# 4  6322759cc5cba579934445f1          11B              44.00      2      1
#
#    Floors                           Year Building_type      Heating  ...  \
# 0       5                           1971       Mūrinis  [centrinis]  ...
# 1       5  1978 statyba, 2011 renovacija      Blokinis  [centrinis]  ...
# 2       5  1940 statyba, 2010 renovacija   Monolitinis    [elektra]  ...
# 3       5                           1978      Blokinis  [centrinis]  ...
# 4       3  2014 statyba, 2014 renovacija       Mūrinis    [dujinis]  ...
#
#       City      District Dorm Days_active Views_per_day Saved_per_day  \
# ...

# %%
butaik['Ad_type'] = 'Parduodamas'
butaiv['Ad_type'] = 'Parduodamas'

nuomak['Ad_type'] = 'Nuoma'
nuomav['Ad_type'] = 'Nuoma'

butaik['City'] = 'Kaunas'
butaiv['City'] = 'Vilnius'

nuomak['City'] = 'Kaunas'
nuomav['City'] = 'Vilnius'

# combine dataframes
butai = pd.concat([butaik, butaiv, nuomak, nuomav], ignore_index=True)

# %%
butai['Heating'] = butai['Heating'].apply(lambda x: x[0] if x else '')

# %%
butai.to_csv('butai.csv', index=False)
